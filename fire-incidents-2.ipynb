# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fires = pd.read_csv('fire-incidents.csv')
fires_by_neighborhood = fires.groupby('neighborhood').size().sort_values(ascending=False)

most_incidents = fires.head(1)
#neighborhood with the most fire incidents (Carrick - 237)

# %%
fires_by_neighborhood.head(10).plot.bar()
#ten neighborhoods with most fire incidents

# %%
fires_by_neighborhood.head(30).plot.bar()

# %%
#shows trend of 30 neighborhoods with highest amount of fire incidents

# %%
fires_by_neighborhood.tail(30).plot.bar()

# %%
#trend of 30 neighborhoods with least fire incidents

# %%
least_incidents = fires_by_neighborhood.tail(1)
#least_incidents neighborhood (Regent Square - 6)

# %%
fires_by_neighborhood.describe()
# Out:
# count     91.000000
# mean      74.197802
# std       57.272491
# min        6.000000
# 25%       28.000000
# 50%       56.000000
# 75%      106.500000
# max      237.000000
# dtype: float64

# %%
fire_types = fires.groupby(['neighborhood', 'type_description'])['type_description'].count()
#for key,item in fire_type:
  #a_group = fire_type.get_group(key)
  #print(a_group, "\n")
fire_typesdf = pd.DataFrame(fire_types)
#fires_by_neighborhood['neighborhood'] == "Regent Square"
fire_typesdf
# Out:
#                                                                   type_description
# neighborhood     type_description
# Allegheny Center Brush or brush-and-grass mixture fire                           3
#                  Building fire                                                   2
#                  Cooking fire, confined to container                            16
#                  Dumpster or other outside trash receptacle fire                 5
#                  Fire in portable building, fixed location                       1
# ...                                                                            ...
# Windgap          Natural vegetation fire, Other                                  1
#                  Outside rubbish fire, Other                                     2
#                  Outside rubbish, trash or waste fire                            1
#                  Special outside fire, Other                                     1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-06116ca9f91c> in <module>
# ----> 1 fire_types.row()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'row'
